# %% [markdown]
# <a href="https://colab.research.google.com/github/euigyuhwang/BigFig/blob/gh-pages/Hello_world_tensorflow%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # The Hello World of Deep Learning with Neural Networks

# %% [markdown]
# TensorFlow Hello World 코드에 오신 걸 환영합니다.
#
# 우리는 TensorFlow keras API를 사용해 간단한 함수를 학습해볼 겁니다.
#
# 첫 번째 인공신경망을 만들어보면서, 우리의 목표는 두 변수 간의 관계를 학습시키는 것입니다.
#
# ```
# float hw_function(float x){
#     float y = (2 * x) - 1;
#     return y;
# }
# ```
#
# 어떻게 위의 x,y에 대한 함수입니다. 인공신경망은 어떻게 학습할까요? 바로 우리가 ML에서 배웠듯이 데이터를 사용하는 것입니다.
# X,Y 데이터를 입력하면서 두 변수의 관계를 학습시키도록 할 겁니다.

# %% [markdown]
# ## Imports
# numpy의 별칭이 np인 것처럼 tensorflow의 별칭 tf를 사용합니다.

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %% [markdown]
# ## Define and Compile the Neural Network
#
# 다음으로 우리는 가능한 가장 간단한 인공신경망을 만들겁니다. 인공신경망은 오직 1개의 레이어를 갖고, 그 레이어는 하나의 뉴런을 갖습니다.
# 또한 입력의 shape은 1입니다.

# %%
my_layer = keras.layers.Dense(1, activation=None, input_shape=[1])
model = tf.keras.Sequential([my_layer])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_1 (Dense)              (None, 1)                 2
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# %% [markdown]
# 다음으로 우리는 우리의 인공신경망을 compile 해줄겁니다. 이때 텐서플로우는 모델의 구조를 결정 짓습니다.
#
# 또한 우리는 2개의 함수를 특정해줍니다. 바로 loss와 optimizer입니다.
#
# (1) loss는 문제에 적합한 목적함수를 사용해주어야 합니다. 우리는 regression 문제이기 때문에 mean_squared_error를 사용합니다.
# loss의 입력으로 '목적함수의 이름' 또는 tf.keras.losses 안의 instance가 가능합니다.
#
# (2) optimizer는 stochastic gradient descent를 선택했습니다.
# loss의 입력으로 '최적화 알고리즘의 이름' 또는 tf.keras.optimizers 안의 instance가 가능합니다.

# %%
#dir(tf.keras.losses)

# %%
dir(tf.keras.optimizers)
# Out:
# ['Adadelta',
#  'Adagrad',
#  'Adam',
#  'Adamax',
#  'Ftrl',
#  'Nadam',
#  'Optimizer',
#  'RMSprop',
#  'SGD',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_sys',
#  'deserialize',
#  'get',
#  'schedules',
#  'serialize']

# %%
model.compile(optimizer='sgd', loss='mean_squared_error') 
# == model.compile(optimizer=tf.keras.optimizers.SGD(), loss=tf.keras.losses.mse)

# %% [markdown]
# ## Providing the Data

# %% [markdown]
# TensorFlow는 numpy array를 데이터 입력형태로 허용합니다.
#
# numpy array를 사용해 y=2x-1의 관계를 갖는 데이터를 만들어줍니다.

# %%
xs = np.array([-1.0,  0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

# %% [markdown]
# # Training the Neural Network

# %% [markdown]
# 이제 EPOCHS의 횟수만큼 데이터 전체를 모델에 입력하여 학습시킬 것입니다.
# 위에서 정의해준 y = 2x - 1의 관계를 갖는 Xs와 Ys를 model.fit의 입력으로 줍니다.

# %%
model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 477ms/step - loss: 8.4495
# Epoch 2/500
# 1/1 [==============================] - 0s 5ms/step - loss: 6.8483
# Epoch 3/500
# 1/1 [==============================] - 0s 5ms/step - loss: 5.5844
# Epoch 4/500
# 1/1 [==============================] - 0s 4ms/step - loss: 4.5859
# Epoch 5/500
# 1/1 [==============================] - 0s 6ms/step - loss: 3.7965
# Epoch 6/500
# 1/1 [==============================] - 0s 3ms/step - loss: 3.1715
# Epoch 7/500
# 1/1 [==============================] - 0s 3ms/step - loss: 2.6760
# Epoch 8/500
# 1/1 [==============================] - 0s 9ms/step - loss: 2.2825
# Epoch 9/500
# 1/1 [==============================] - 0s 4ms/step - loss: 1.9692
# Epoch 10/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.7192
# Epoch 11/500
# 1/1 [==============================] - 0s 4ms/step - loss: 1.5190
# Epoch 12/500
# 1/1 [==============================] - 0s 4ms/step - loss: 1.3581
# ...

# %% [markdown]
# 학습이 잘 됐다면 모델은 x와 y 사이의 관계를 학습했을 것입니다.
#
# model.predict를 사용해 임의의 x에 대해 y를 예측할 수 있습니다.
#
# 예를 들어 x = 10을 넣어볼까요? y는 무엇이 될까요.

# %%
print(model.predict([10.0]))
# Out:
# [[18.98322]]

# %%
model.get_weights()
# Out:
# [array([[1.9975677]], dtype=float32), array([-0.99245906], dtype=float32)]
